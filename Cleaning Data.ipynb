# %%
# import dependencies 
import pandas as pd
import numpy as np

# %%
# turn data file into data frame
df = pd.read_csv('merged_df_1127.csv')

# %%
# replace NaN's with 0
df['Recipient Parent Duns'] = df['Recipient Parent Duns'].fillna(0)
# replace NaN's with 'None'
df['Set Aside Type'] = df['Set Aside Type'].fillna('NONE')
# replace NaN's with 'No Set Aside Used'
df['Set Aside Description'] = df['Set Aside Description'].fillna('NO SET ASIDE USED.')

# %%
# fill any other blanks with empty string
df = df.fillna('')
# delete unneeded column
del df['Unnamed: 0']

# %%
# add leading zeros to make 9 digits
df['Recipient DUNS Number'] = df['Recipient DUNS Number'].astype(str).str.zfill(9)

# %%
# add leading zeros to make 9 digits - not sure why this one isnt working
df['Recipient Parent Duns'] = df['Recipient Parent Duns'].astype(str).str.zfill(9)

# %%
# add column with our own set aside groups
df['Set Aside Groups'] = df['Set Aside Type']
# replace values
df['Set Aside Groups'] = df['Set Aside Groups'].replace('8A','8(a)')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('8AN','8(a)')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('BI','Buy Indian')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('EDWOSB','Woman Owned')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('EDWOSBSS','Woman Owned')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('HZC','HubZone')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('HZS','HubZone')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('IEE','Indian Enterprise')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('ISBEE','Indian SB Enterprise')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('NONE','Open')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('SBA','Small Biz')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('SBP','Small Biz')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('SDVOSBC','Disabled Veteran')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('SDVOSBS','Disabled Veteran')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('VSA','Veteran')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('VSS','Veteran')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('WOSB','Woman Owned')
df['Set Aside Groups'] = df['Set Aside Groups'].replace('WOSBSS','Woman Owned')

# add sole source column 
df['Sole Source?'] = df['Set Aside Type']
# replace values 
df['Sole Source?'] = df['Sole Source?'].replace('8A','N')
df['Sole Source?'] = df['Sole Source?'].replace('8AN','Y')
df['Sole Source?'] = df['Sole Source?'].replace('BI','N')
df['Sole Source?'] = df['Sole Source?'].replace('EDWOSB','N')
df['Sole Source?'] = df['Sole Source?'].replace('EDWOSBSS','Y')
df['Sole Source?'] = df['Sole Source?'].replace('HZC','N')
df['Sole Source?'] = df['Sole Source?'].replace('HZS','Y')
df['Sole Source?'] = df['Sole Source?'].replace('IEE','N')
df['Sole Source?'] = df['Sole Source?'].replace('ISBEE','N')
df['Sole Source?'] = df['Sole Source?'].replace('NONE','N')
df['Sole Source?'] = df['Sole Source?'].replace('SBA','N')
df['Sole Source?'] = df['Sole Source?'].replace('SBP','N')
df['Sole Source?'] = df['Sole Source?'].replace('SDVOSBC','N')
df['Sole Source?'] = df['Sole Source?'].replace('SDVOSBS','Y')
df['Sole Source?'] = df['Sole Source?'].replace('VSA','N')
df['Sole Source?'] = df['Sole Source?'].replace('VSS','Y')
df['Sole Source?'] = df['Sole Source?'].replace('WOSB','N')
df['Sole Source?'] = df['Sole Source?'].replace('WOSBSS','Y')

# clean contract award type column 
df['Contract Award Type'] = df['Contract Award Type'].replace('DO','DELIVERY ORDER')
df['Contract Award Type'] = df['Contract Award Type'].replace('PO','PURCHASE ORDER')

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#         Award ID                      generated_internal_id  \
# 0           YY01      CONT_AWD_YY01_9700_W81K0409D0070_9700
# 1           YY01      CONT_AWD_YY01_9700_W81K0409D0066_9700
# 2  W91ZRU21C0002  CONT_AWD_W91ZRU21C0002_9700_-NONE-_-NONE-
# 3  W91ZRU19P5014  CONT_AWD_W91ZRU19P5014_9700_-NONE-_-NONE-
# 4  W91ZRU19P0030  CONT_AWD_W91ZRU19P0030_9700_-NONE-_-NONE-
#
#               Recipient Name Recipient DUNS Number Base Obligation Date  \
# 0  ADVANCIA AERONAUTICS, LLC             792283272            8/13/2009
# 1  ADVANCIA AERONAUTICS, LLC             792283272            6/14/2010
# 2          AHTNA GLOBAL, LLC             080409325            12/7/2020
# 3          AHTNA GLOBAL, LLC             080409325            9/26/2019
# 4              ARCTICOM, LLC             079766453            9/26/2019
#
#    Start Date    End Date Place of Performance State Code  Award Amount  \
# 0   8/13/2009   8/31/2014                              KS    1438924.40
# 1   6/11/2010   9/30/2012                              OK     870560.35
# 2  12/12/2020  12/11/2021                              AK     134756.00
# 3   9/26/2019  11/30/2021                              AK     308684.00
# 4   9/26/2019  12/25/2019                              AK      94270.50
#
#    Awarding Agency Code Awarding Sub Agency Code  Contract Award Type  \
# 0                    97                     2100       DELIVERY ORDER
# 1                    97                     2100       DELIVERY ORDER
# 2                    97                     2100  DEFINITIVE CONTRACT
# 3                    97                     2100       PURCHASE ORDER
# 4                    97                     2100       PURCHASE ORDER
#
#   Award Type Funding Agency Code Funding Sub Agency Code COVID-19 Outlays  \
# 0                           97.0                    2100
# 1                           97.0                    2100
# 2                           97.0                    2100
# 3                           97.0                    5700
# 4                           97.0                    2100
#
#   COVID-19 Obligations                                Business Categories  \
# 0                       ['Category Business', 'Federally Funded Resear...
# 1                       ['Category Business', 'Federally Funded Resear...
# 2                       ['8(a) Program Participant', 'Alaskan Native C...
# 3                       ['8(a) Program Participant', 'Alaskan Native C...
# 4                       ['8(a) Program Participant', 'Alaskan Native C...
#
#   Set Aside Type             Set Aside Description     NAICS  \
# 0            SBA  SMALL BUSINESS SET ASIDE - TOTAL  621111.0
# 1            SBA  SMALL BUSINESS SET ASIDE - TOTAL  621111.0
# 2            8AN                  8(A) SOLE SOURCE  541611.0
# 3            8AN                  8(A) SOLE SOURCE  561320.0
# 4            8AN                  8(A) SOLE SOURCE  517919.0
#
#                                    NAICS Description  \
# 0  OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...
# 1  OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...
# 2  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 3                            TEMPORARY HELP SERVICES
# 4                       ALL OTHER TELECOMMUNICATIONS
#
#       Recipient Parent Name Recipient Parent Duns Place of Performance City  \
# 0  ADVANCIA AERONAUTICS LLC           792283272.0          FORT LEAVENWORTH
# 1  ADVANCIA AERONAUTICS LLC           792283272.0                 FORT SILL
# 2         AHTNA GLOBAL  LLC            69586055.0           FORT RICHARDSON
# 3         AHTNA GLOBAL  LLC            69586055.0                      JBER
# 4             ARCTICOM  LLC            79766453.0           FORT RICHARDSON
#
#   Last Modified Date Potential End Date  Total Obligated Amount  \
# 0      8/8/2013 0:00     8/31/2014 0:00              1438924.40
# 1     11/8/2012 0:00     9/30/2012 0:00               870560.35
# 2    2/18/2021 16:18    12/11/2025 0:00               134756.00
# 3    5/27/2021 16:23    11/30/2021 0:00               308684.00
# 4     10/7/2021 9:37    12/25/2019 0:00                94270.50
#
#   Set Aside Groups Sole Source?
# 0        Small Biz            N
# 1        Small Biz            N
# 2             8(a)            Y
# 3             8(a)            Y
# 4             8(a)            Y

# %%
df.to_csv('cleaned_data_12.1.csv')
