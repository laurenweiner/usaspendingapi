# %%
# import dependencies
import requests
import pandas as pd
import pprint

# %%
# clear list 
award_list=[]
award_list.clear()

# %%
# access active 8a firmst list 
datafile = 'SBA 8a Active Firms with Recip ID.csv'

# create dataframe
usa_df = pd.read_csv(datafile)

# change DUNS number to string 
#usa_df["DUNS_Number"] = usa_df["DUNS_Number"].astype(str)

# pull duns column from data frame to use as list in for loop 
duns_list = usa_df["DUNS"].astype(str).str.zfill(9).tolist()

# %%
num_list = list(range(1,20000))

# %%
# spending_by_award
award_endpoint = 'https://api.usaspending.gov/api/v2/search/spending_by_award/'

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[0:500]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# processing page 121
# processing page 122
# processing page 123
# processing page 124
# processing page 125
# processing page 126
# processing page 127
# processing page 128
# processing page 129
# processing page 130
# processing page 131
# processing page 132
# processing page 133
# processing page 134
# processing page 135
# processing page 136
# processing page 137
# processing page 138
# processing page 139
# processing page 140
# processing page 141
# processing page 142
# processing page 143
# processing page 144
# processing page 145
# processing page 146
# processing page 147
# processing page 148
# processing page 149
# processing page 150
# processing page 151
# processing page 152
# processing page 153
# processing page 154
# processing page 155
# processing page 156
# processing page 157
# processing page 158
# processing page 159
# processing page 160
# processing page 161
# processing page 162
# processing page 163
# processing page 164
# processing page 165
# processing page 166
# processing page 167
# processing page 168
# processing page 169
# processing page 170
# processing page 171
# processing page 172
# processing page 173
# processing page 174
# processing page 175
# processing page 176
# processing page 177
# processing page 178
# processing page 179
# processing page 180
# processing page 181
# processing page 182
# processing page 183
# processing page 184
# processing page 185
# processing page 186
# processing page 187
# processing page 188
# processing page 189
# processing page 190
# processing page 191
# processing page 192
# processing page 193
# processing page 194
# processing page 195
# processing page 196
# processing page 197
# processing page 198
# processing page 199
# processing page 200
# processing page 201
# processing page 202
# processing page 203
# processing page 204
# processing page 205
# processing page 206
# processing page 207
# processing page 208
# processing page 209
# processing page 210
# processing page 211
# processing page 212
# processing page 213
# processing page 214
# processing page 215
# processing page 216
# processing page 217
# processing page 218
# processing page 219
# processing page 220
# processing page 221
# processing page 222
# processing page 223
# processing page 224
# processing page 225
# processing page 226
# processing page 227
# processing page 228
# processing page 229
# processing page 230
# processing page 231
# processing page 232
# processing page 233
# processing page 234
# processing page 235
# page 235 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[500:1000]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# processing page 121
# processing page 122
# processing page 123
# processing page 124
# processing page 125
# processing page 126
# processing page 127
# page 127 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[1000:1500]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# processing page 121
# processing page 122
# processing page 123
# processing page 124
# processing page 125
# processing page 126
# processing page 127
# processing page 128
# processing page 129
# processing page 130
# processing page 131
# processing page 132
# processing page 133
# processing page 134
# processing page 135
# processing page 136
# processing page 137
# processing page 138
# processing page 139
# processing page 140
# processing page 141
# processing page 142
# processing page 143
# processing page 144
# processing page 145
# processing page 146
# processing page 147
# processing page 148
# processing page 149
# processing page 150
# processing page 151
# processing page 152
# processing page 153
# processing page 154
# processing page 155
# processing page 156
# processing page 157
# processing page 158
# processing page 159
# processing page 160
# processing page 161
# processing page 162
# processing page 163
# processing page 164
# processing page 165
# processing page 166
# processing page 167
# processing page 168
# processing page 169
# processing page 170
# processing page 171
# processing page 172
# processing page 173
# processing page 174
# processing page 175
# processing page 176
# processing page 177
# processing page 178
# processing page 179
# processing page 180
# processing page 181
# processing page 182
# processing page 183
# processing page 184
# processing page 185
# processing page 186
# processing page 187
# processing page 188
# processing page 189
# processing page 190
# processing page 191
# processing page 192
# processing page 193
# processing page 194
# processing page 195
# processing page 196
# processing page 197
# processing page 198
# processing page 199
# processing page 200
# processing page 201
# processing page 202
# processing page 203
# processing page 204
# processing page 205
# processing page 206
# processing page 207
# processing page 208
# processing page 209
# processing page 210
# processing page 211
# processing page 212
# processing page 213
# processing page 214
# processing page 215
# processing page 216
# processing page 217
# processing page 218
# processing page 219
# processing page 220
# processing page 221
# processing page 222
# processing page 223
# processing page 224
# processing page 225
# processing page 226
# processing page 227
# processing page 228
# processing page 229
# processing page 230
# processing page 231
# processing page 232
# processing page 233
# processing page 234
# processing page 235
# processing page 236
# processing page 237
# processing page 238
# processing page 239
# processing page 240
# processing page 241
# processing page 242
# processing page 243
# processing page 244
# processing page 245
# processing page 246
# processing page 247
# processing page 248
# processing page 249
# processing page 250
# processing page 251
# processing page 252
# processing page 253
# processing page 254
# processing page 255
# processing page 256
# processing page 257
# processing page 258
# processing page 259
# processing page 260
# processing page 261
# processing page 262
# processing page 263
# processing page 264
# processing page 265
# processing page 266
# processing page 267
# processing page 268
# processing page 269
# processing page 270
# processing page 271
# processing page 272
# processing page 273
# processing page 274
# processing page 275
# processing page 276
# processing page 277
# processing page 278
# processing page 279
# processing page 280
# processing page 281
# processing page 282
# processing page 283
# processing page 284
# processing page 285
# processing page 286
# processing page 287
# processing page 288
# processing page 289
# processing page 290
# processing page 291
# processing page 292
# processing page 293
# processing page 294
# processing page 295
# processing page 296
# processing page 297
# processing page 298
# processing page 299
# processing page 300
# processing page 301
# processing page 302
# processing page 303
# processing page 304
# processing page 305
# processing page 306
# processing page 307
# processing page 308
# processing page 309
# processing page 310
# processing page 311
# processing page 312
# processing page 313
# processing page 314
# processing page 315
# processing page 316
# processing page 317
# processing page 318
# processing page 319
# processing page 320
# processing page 321
# processing page 322
# processing page 323
# processing page 324
# processing page 325
# processing page 326
# processing page 327
# processing page 328
# processing page 329
# processing page 330
# processing page 331
# processing page 332
# processing page 333
# processing page 334
# processing page 335
# processing page 336
# processing page 337
# processing page 338
# processing page 339
# processing page 340
# processing page 341
# processing page 342
# processing page 343
# processing page 344
# processing page 345
# processing page 346
# processing page 347
# processing page 348
# processing page 349
# processing page 350
# processing page 351
# processing page 352
# processing page 353
# processing page 354
# processing page 355
# processing page 356
# processing page 357
# processing page 358
# processing page 359
# processing page 360
# processing page 361
# processing page 362
# processing page 363
# processing page 364
# processing page 365
# processing page 366
# processing page 367
# processing page 368
# processing page 369
# processing page 370
# processing page 371
# processing page 372
# page 372 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[1500:2000]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# processing page 121
# processing page 122
# processing page 123
# processing page 124
# processing page 125
# processing page 126
# processing page 127
# processing page 128
# processing page 129
# processing page 130
# processing page 131
# processing page 132
# processing page 133
# processing page 134
# processing page 135
# processing page 136
# processing page 137
# processing page 138
# processing page 139
# processing page 140
# processing page 141
# processing page 142
# processing page 143
# processing page 144
# processing page 145
# processing page 146
# processing page 147
# processing page 148
# processing page 149
# processing page 150
# processing page 151
# processing page 152
# page 152 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[2000:2500]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# page 106 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[2500:3000]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# processing page 121
# processing page 122
# processing page 123
# processing page 124
# processing page 125
# processing page 126
# processing page 127
# processing page 128
# processing page 129
# processing page 130
# processing page 131
# processing page 132
# processing page 133
# processing page 134
# processing page 135
# processing page 136
# processing page 137
# processing page 138
# processing page 139
# processing page 140
# processing page 141
# processing page 142
# processing page 143
# processing page 144
# processing page 145
# processing page 146
# processing page 147
# processing page 148
# processing page 149
# processing page 150
# processing page 151
# processing page 152
# processing page 153
# processing page 154
# processing page 155
# processing page 156
# processing page 157
# processing page 158
# processing page 159
# processing page 160
# processing page 161
# processing page 162
# processing page 163
# processing page 164
# processing page 165
# processing page 166
# processing page 167
# page 167 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[3000:3500]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# processing page 121
# processing page 122
# processing page 123
# processing page 124
# processing page 125
# processing page 126
# processing page 127
# processing page 128
# processing page 129
# processing page 130
# processing page 131
# processing page 132
# processing page 133
# processing page 134
# processing page 135
# processing page 136
# processing page 137
# processing page 138
# processing page 139
# processing page 140
# processing page 141
# processing page 142
# processing page 143
# processing page 144
# processing page 145
# processing page 146
# processing page 147
# processing page 148
# processing page 149
# page 149 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[3500:4000]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# page 120 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[4000:4500]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# processing page 113
# processing page 114
# processing page 115
# processing page 116
# processing page 117
# processing page 118
# processing page 119
# processing page 120
# processing page 121
# processing page 122
# processing page 123
# processing page 124
# processing page 125
# processing page 126
# processing page 127
# processing page 128
# processing page 129
# processing page 130
# processing page 131
# processing page 132
# processing page 133
# processing page 134
# processing page 135
# processing page 136
# processing page 137
# processing page 138
# processing page 139
# processing page 140
# processing page 141
# processing page 142
# processing page 143
# processing page 144
# processing page 145
# processing page 146
# processing page 147
# processing page 148
# processing page 149
# processing page 150
# processing page 151
# processing page 152
# processing page 153
# processing page 154
# processing page 155
# processing page 156
# processing page 157
# processing page 158
# processing page 159
# processing page 160
# processing page 161
# processing page 162
# processing page 163
# processing page 164
# processing page 165
# processing page 166
# processing page 167
# processing page 168
# processing page 169
# processing page 170
# processing page 171
# processing page 172
# processing page 173
# processing page 174
# processing page 175
# processing page 176
# processing page 177
# processing page 178
# processing page 179
# processing page 180
# processing page 181
# processing page 182
# processing page 183
# processing page 184
# processing page 185
# processing page 186
# processing page 187
# processing page 188
# processing page 189
# processing page 190
# processing page 191
# processing page 192
# processing page 193
# processing page 194
# processing page 195
# processing page 196
# processing page 197
# processing page 198
# processing page 199
# processing page 200
# processing page 201
# processing page 202
# processing page 203
# processing page 204
# processing page 205
# processing page 206
# processing page 207
# processing page 208
# processing page 209
# processing page 210
# processing page 211
# processing page 212
# processing page 213
# processing page 214
# processing page 215
# processing page 216
# processing page 217
# processing page 218
# processing page 219
# processing page 220
# processing page 221
# processing page 222
# processing page 223
# processing page 224
# processing page 225
# processing page 226
# processing page 227
# processing page 228
# processing page 229
# processing page 230
# processing page 231
# processing page 232
# processing page 233
# processing page 234
# processing page 235
# processing page 236
# processing page 237
# processing page 238
# processing page 239
# processing page 240
# processing page 241
# processing page 242
# processing page 243
# processing page 244
# processing page 245
# processing page 246
# processing page 247
# processing page 248
# processing page 249
# processing page 250
# processing page 251
# processing page 252
# processing page 253
# processing page 254
# processing page 255
# processing page 256
# processing page 257
# processing page 258
# processing page 259
# processing page 260
# processing page 261
# page 261 is empty

# %%
for i in num_list: 

    # filters
    data =     {
          "subawards": 'false',
          "limit": 100,
          "page": i,
          "filters": {
              "award_type_codes": ["A", "B", "C","D"],
              "recipient_search_text": duns_list[4500:4925]
          },
          "fields": [
              "Award ID",
              "Recipient Name",
              "Recipient DUNS Number",
              "Start Date",
              "End Date",
              "Award Amount",
              "Awarding Agency",
              "Awarding Sub Agency",
              "Contract Award Type",
              "Award Type",
              "Funding Agency",
              "Funding Sub Agency"
          ]
      }
    
    print(f'processing page {i}')

    # post request 
    k = requests.post(url = award_endpoint, json = data)
    response_k = k.json()
    results_k = response_k['results']
    

    # go through list of awards and organize 
    for award in results_k:
        award_id = award["Award ID"]
        recipient_name = award["Recipient Name"]
        recipient_duns = award["Recipient DUNS Number"]
        start_date = award["Start Date"]
        end_date = award["End Date"]
        award_amount = award["Award Amount"]
        awarding_agency = award["Awarding Agency"]
        awarding_subagency = award["Awarding Sub Agency"]
        contract_award_type = award["Contract Award Type"]
        award_type = award["Award Type"]
        funding_agency = award["Funding Agency"]
        funding_subagency = award["Funding Sub Agency"]
        award_list.append({'Award ID':award_id,
                           'Recipient Name':recipient_name, 
                           'Recipient DUNS Number':recipient_duns,
                          'Start Date':start_date,
                          'End Date':end_date,
                          'Award Amount':award_amount,
                          'Awarding Agency':awarding_agency,
                          'Awarding Sub Agency':awarding_subagency,
                          'Contract Award Type':contract_award_type,
                          'Award Type':award_type,
                          'Funding Agency':funding_agency,
                          'Funding Sub Agency':funding_subagency
                          })
            
    if not results_k:
        print(f'page {i} is empty')
        break
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# processing page 49
# processing page 50
# processing page 51
# processing page 52
# processing page 53
# processing page 54
# processing page 55
# processing page 56
# processing page 57
# processing page 58
# processing page 59
# processing page 60
# processing page 61
# processing page 62
# processing page 63
# processing page 64
# processing page 65
# processing page 66
# processing page 67
# processing page 68
# processing page 69
# processing page 70
# processing page 71
# processing page 72
# processing page 73
# processing page 74
# processing page 75
# processing page 76
# processing page 77
# processing page 78
# processing page 79
# processing page 80
# processing page 81
# processing page 82
# processing page 83
# processing page 84
# processing page 85
# processing page 86
# processing page 87
# processing page 88
# processing page 89
# processing page 90
# processing page 91
# processing page 92
# processing page 93
# processing page 94
# processing page 95
# processing page 96
# processing page 97
# processing page 98
# processing page 99
# processing page 100
# processing page 101
# processing page 102
# processing page 103
# processing page 104
# processing page 105
# processing page 106
# processing page 107
# processing page 108
# processing page 109
# processing page 110
# processing page 111
# processing page 112
# page 112 is empty

# %%
# make data frame to view data easily 
awards_df = pd.DataFrame(award_list, columns = ['Award ID',
                                                'Recipient Name',
                                                'Recipient DUNS Number',
                                                'Start Date','End Date',
                                                'Award Amount', 
                                                'Awarding Agency',
                                                'Awarding Sub Agency',
                                                'Contract Award Type',
                                                'Award Type',
                                                'Funding Agency',
                                                'Funding Sub Agency'])
awards_df
# Out:
#              Award ID             Recipient Name Recipient DUNS Number  \
# 0                YY01  ADVANCIA AERONAUTICS, LLC             792283272
# 1                YY01  ADVANCIA AERONAUTICS, LLC             792283272
# 2       W91ZRU21C0002          AHTNA GLOBAL, LLC             080409325
# 3       W91ZRU19P5014          AHTNA GLOBAL, LLC             080409325
# 4       W91ZRU19P0030              ARCTICOM, LLC             079766453
# ...               ...                        ...                   ...
# 178635           0001        TV GUY ORLANDO, LLC             002047015
# 178636           0001         WORLD SERVICES LLC             044670973
# 178637           0001                 WERIS, INC             791282143
# 178638           0001          TRI-LOGISTICS LLC             961815805
# 178639           0001        TTW SOLUTIONS, INC.             809779254
#
#         Start Date    End Date  Award Amount  \
# 0       2009-08-13  2014-08-31    1438924.40
# 1       2010-06-11  2012-09-30     870560.35
# 2       2020-12-12  2021-12-11     134756.00
# 3       2019-09-26  2021-11-30     308684.00
# 4       2019-09-26  2019-12-25      94270.50
# ...            ...         ...           ...
# 178635  2013-10-01  2014-09-30      16990.40
# 178636  2017-09-27  2018-09-26      25054.10
# 178637  2018-02-12  2016-07-13     229675.78
# 178638  2016-09-28  2026-09-29    1994137.24
# 178639  2016-09-26  2017-09-26    1151776.80
#
#                                     Awarding Agency  \
# 0                             Department of Defense
# 1                             Department of Defense
# 2                             Department of Defense
# 3                             Department of Defense
# 4                             Department of Defense
# ...                                             ...
# 178635                        Department of Defense
# 178636  Department of Housing and Urban Development
# 178637                 Department of Transportation
# 178638                 Department of Transportation
# 178639           Consumer Product Safety Commission
#
#                                 Awarding Sub Agency  Contract Award Type  \
# 0                            Department of the Army                   DO
# 1                            Department of the Army                   DO
# 2                            Department of the Army  DEFINITIVE CONTRACT
# 3                            Department of the Army       PURCHASE ORDER
# 4                            Department of the Army       PURCHASE ORDER
# ...                                             ...                  ...
# 178635                  Department of the Air Force                   DO
# 178636  Department of Housing and Urban Development       DELIVERY ORDER
# 178637               Federal Highway Administration       DELIVERY ORDER
# 178638              Federal Aviation Administration       DELIVERY ORDER
# 178639           Consumer Product Safety Commission       DELIVERY ORDER
#
#        Award Type                               Funding Agency  \
# 0            None                        Department of Defense
# 1            None                        Department of Defense
# 2            None                        Department of Defense
# 3            None                        Department of Defense
# 4            None                        Department of Defense
# ...           ...                                          ...
# 178635       None                        Department of Defense
# 178636       None  Department of Housing and Urban Development
# 178637       None                 Department of Transportation
# 178638       None                 Department of Transportation
# 178639       None           Consumer Product Safety Commission
#
#                                  Funding Sub Agency
# 0                            Department of the Army
# 1                            Department of the Army
# 2                            Department of the Army
# 3                       Department of the Air Force
# 4                            Department of the Army
# ...                                             ...
# 178635                  Department of the Air Force
# 178636  Department of Housing and Urban Development
# 178637               Federal Highway Administration
# 178638              Federal Aviation Administration
# 178639           Consumer Product Safety Commission
#
# [178640 rows x 12 columns]

# %%
award_list
# Out:
# [{'Award ID': 'YY01',
#   'Recipient Name': 'ADVANCIA AERONAUTICS, LLC',
#   'Recipient DUNS Number': '792283272',
#   'Start Date': '2009-08-13',
#   'End Date': '2014-08-31',
#   'Award Amount': 1438924.4,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'YY01',
#   'Recipient Name': 'ADVANCIA AERONAUTICS, LLC',
#   'Recipient DUNS Number': '792283272',
#   'Start Date': '2010-06-11',
#   'End Date': '2012-09-30',
#   'Award Amount': 870560.35,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU21C0002',
#   'Recipient Name': 'AHTNA GLOBAL, LLC',
#   'Recipient DUNS Number': '080409325',
#   'Start Date': '2020-12-12',
#   'End Date': '2021-12-11',
#   'Award Amount': 134756.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU19P5014',
#   'Recipient Name': 'AHTNA GLOBAL, LLC',
#   'Recipient DUNS Number': '080409325',
#   'Start Date': '2019-09-26',
#   'End Date': '2021-11-30',
#   'Award Amount': 308684.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Air Force'},
#  {'Award ID': 'W91ZRU19P0030',
#   'Recipient Name': 'ARCTICOM, LLC',
#   'Recipient DUNS Number': '079766453',
#   'Start Date': '2019-09-26',
#   'End Date': '2019-12-25',
#   'Award Amount': 94270.5,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU18P0005',
#   'Recipient Name': 'AHTNA GLOBAL, LLC',
#   'Recipient DUNS Number': '080409325',
#   'Start Date': '2018-01-31',
#   'End Date': '2020-02-04',
#   'Award Amount': 236651.08,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU18C0004',
#   'Recipient Name': 'AHTNA GLOBAL, LLC',
#   'Recipient DUNS Number': '080409325',
#   'Start Date': '2018-09-21',
#   'End Date': '2020-12-11',
#   'Award Amount': 270562.06,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU18C0001',
#   'Recipient Name': 'AHTNA GLOBAL, LLC',
#   'Recipient DUNS Number': '080409325',
#   'Start Date': '2018-02-20',
#   'End Date': '2022-02-19',
#   'Award Amount': 1971972.57,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU17P0036',
#   'Recipient Name': 'ARCTICOM, LLC',
#   'Recipient DUNS Number': '079766453',
#   'Start Date': '2017-09-29',
#   'End Date': '2018-01-31',
#   'Award Amount': 64552.59,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Air Force'},
#  {'Award ID': 'W91ZRU17P0013',
#   'Recipient Name': 'ARCTICOM, LLC',
#   'Recipient DUNS Number': '079766453',
#   'Start Date': '2017-05-23',
#   'End Date': '2017-06-30',
#   'Award Amount': 8970.34,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Air Force'},
#  {'Award ID': 'W91ZRU17P0004',
#   'Recipient Name': 'AHTNA ENVIRONMENTAL, INC.',
#   'Recipient DUNS Number': '966659117',
#   'Start Date': '2017-01-01',
#   'End Date': '2018-02-03',
#   'Award Amount': 79468.8,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU17C0002',
#   'Recipient Name': 'ALUTIIQ CONSTRUCTION SERVICES, LLC',
#   'Recipient DUNS Number': '079722826',
#   'Start Date': '2016-11-30',
#   'End Date': '2018-12-31',
#   'Award Amount': 3825031.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Air Force'},
#  {'Award ID': 'W91ZRU16P0094',
#   'Recipient Name': 'A3 SYSTEMS CORPORATION',
#   'Recipient DUNS Number': '079511256',
#   'Start Date': '2016-09-28',
#   'End Date': '2016-11-29',
#   'Award Amount': 66127.26,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU16P0068',
#   'Recipient Name': 'ARCTICOM, LLC',
#   'Recipient DUNS Number': '079766453',
#   'Start Date': '2016-09-23',
#   'End Date': '2016-12-22',
#   'Award Amount': 91463.02,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Air Force'},
#  {'Award ID': 'W91ZRU15P0063',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2015-09-11',
#   'End Date': '2015-12-10',
#   'Award Amount': 31412.08,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Air Force'},
#  {'Award ID': 'W91ZRU15C0004',
#   'Recipient Name': 'AHTNA ENVIRONMENTAL, INC.',
#   'Recipient DUNS Number': '966659117',
#   'Start Date': '2015-06-12',
#   'End Date': '2020-12-11',
#   'Award Amount': 937987.1,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU13P0101',
#   'Recipient Name': 'ALTITUDE TECHNOLOGIES INC.',
#   'Recipient DUNS Number': '621904622',
#   'Start Date': '2013-08-27',
#   'End Date': '2013-10-31',
#   'Award Amount': 15575.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Air Force'},
#  {'Award ID': 'W91ZRU13C0005',
#   'Recipient Name': 'AHTNA ENVIRONMENTAL, INC.',
#   'Recipient DUNS Number': '966659117',
#   'Start Date': '2013-09-19',
#   'End Date': '2016-03-31',
#   'Award Amount': 5491082.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU13C0003',
#   'Recipient Name': 'AHTNA ENVIRONMENTAL, INC.',
#   'Recipient DUNS Number': '966659117',
#   'Start Date': '2013-06-01',
#   'End Date': '2018-08-31',
#   'Award Amount': 3031665.25,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU12P0099',
#   'Recipient Name': 'ALTITUDE TECHNOLOGIES INC.',
#   'Recipient DUNS Number': '621904622',
#   'Start Date': '2012-09-10',
#   'End Date': '2012-10-31',
#   'Award Amount': 22388.71,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU12P0077',
#   'Recipient Name': 'AHTNA ENVIRONMENTAL, INC.',
#   'Recipient DUNS Number': '966659117',
#   'Start Date': '2012-07-13',
#   'End Date': '2014-08-14',
#   'Award Amount': 168059.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRU08F0076',
#   'Recipient Name': 'ALTITUDE TECHNOLOGIES INC.',
#   'Recipient DUNS Number': '621904622',
#   'Start Date': '2008-08-11',
#   'End Date': '2008-08-14',
#   'Award Amount': 9584.05,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRS19P0046',
#   'Recipient Name': 'APPLIED SYSTEMS & TECHNOLOGY TRANSFER LLC',
#   'Recipient DUNS Number': '964921063',
#   'Start Date': '2019-06-19',
#   'End Date': '2019-07-19',
#   'Award Amount': 60755.67,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRS18P0084',
#   'Recipient Name': 'A3 SYSTEMS CORPORATION',
#   'Recipient DUNS Number': '079511256',
#   'Start Date': '2018-08-13',
#   'End Date': '2018-11-16',
#   'Award Amount': 202923.47,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZRS14M0126',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2014-08-18',
#   'End Date': '2014-10-15',
#   'Award Amount': 16610.44,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK20P0060',
#   'Recipient Name': 'APPLIED DEVELOPMENT, LLC',
#   'Recipient DUNS Number': '078516013',
#   'Start Date': '2020-07-06',
#   'End Date': '2022-01-05',
#   'Award Amount': 123762.48,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK20F0127',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2020-05-20',
#   'End Date': '2023-10-31',
#   'Award Amount': 892178.99,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK19F0184',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2019-09-18',
#   'End Date': '2021-10-31',
#   'Award Amount': 447020.08,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK19F0041',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2019-03-29',
#   'End Date': '2022-03-28',
#   'Award Amount': 930541.9,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK19F0036',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2019-03-21',
#   'End Date': '2022-03-20',
#   'Award Amount': 5401547.79,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK19F0029',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2019-03-13',
#   'End Date': '2022-03-12',
#   'Award Amount': 1181454.78,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK19F0028',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2019-04-15',
#   'End Date': '2022-04-14',
#   'Award Amount': 1505995.21,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK19F0027',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2019-04-01',
#   'End Date': '2022-03-31',
#   'Award Amount': 4614186.26,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK19F0026',
#   'Recipient Name': 'AD HOC RESEARCH ASSOCIATES, LLC',
#   'Recipient DUNS Number': '962516857',
#   'Start Date': '2019-03-01',
#   'End Date': '2021-02-28',
#   'Award Amount': 4107760.91,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK18P0020',
#   'Recipient Name': 'ADDON SERVICES, LLC',
#   'Recipient DUNS Number': '078767330',
#   'Start Date': '2018-02-24',
#   'End Date': '2020-08-25',
#   'Award Amount': 2756648.74,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK17P0189',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2017-08-24',
#   'End Date': '2017-11-02',
#   'Award Amount': 74209.28,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK17P0136',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2017-07-28',
#   'End Date': '2017-09-12',
#   'Award Amount': 74965.49,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK17F1V16',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2017-05-17',
#   'End Date': '2017-07-12',
#   'Award Amount': 472582.27,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK17F1V09',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2017-04-10',
#   'End Date': '2017-05-30',
#   'Award Amount': 102382.75,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK17F1V07',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2017-04-10',
#   'End Date': '2017-05-29',
#   'Award Amount': 142082.02,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK17F0005',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2017-03-07',
#   'End Date': '2017-04-26',
#   'Award Amount': 649999.85,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK16P0303',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2016-09-23',
#   'End Date': '2016-11-11',
#   'Award Amount': 128335.74,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK16P0297',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2016-09-20',
#   'End Date': '2016-11-01',
#   'Award Amount': 100815.7,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK16P0016',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2015-12-10',
#   'End Date': '2016-01-13',
#   'Award Amount': 23934.72,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK16F0030',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2016-08-26',
#   'End Date': '2016-10-17',
#   'Award Amount': 7716.91,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK15F0036',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2015-07-02',
#   'End Date': '2015-08-13',
#   'Award Amount': 46651.15,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK14P0573',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2014-09-26',
#   'End Date': '2014-11-01',
#   'Award Amount': 25772.06,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK14P0566',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2014-09-23',
#   'End Date': '2014-11-21',
#   'Award Amount': 439361.13,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK14P0037',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-12-30',
#   'End Date': '2014-12-29',
#   'Award Amount': 37129.44,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK14F0084',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2014-09-14',
#   'End Date': '2014-12-15',
#   'Award Amount': 101388.95,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK14F0082',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2014-09-25',
#   'End Date': '2014-10-06',
#   'Award Amount': 122804.5,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK14F0005',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-12-19',
#   'End Date': '2014-01-31',
#   'Award Amount': 21025.6,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13P0474',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-09-27',
#   'End Date': '2014-09-26',
#   'Award Amount': 87939.6,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13P0419',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-06-24',
#   'End Date': '2013-07-05',
#   'Award Amount': 233995.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13P0414',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-06-18',
#   'End Date': '2013-07-31',
#   'Award Amount': 152939.76,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13P0394',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2013-09-12',
#   'End Date': '2013-12-13',
#   'Award Amount': 74636.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13P0177',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-05-02',
#   'End Date': '2014-04-22',
#   'Award Amount': 0.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13F0105',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-09-18',
#   'End Date': '2013-12-30',
#   'Award Amount': 65181.82,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13F0096',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-09-12',
#   'End Date': '2013-10-12',
#   'Award Amount': 141864.16,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK13F0022',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-01-17',
#   'End Date': '2014-01-21',
#   'Award Amount': 28830.6,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK12P1436',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2012-03-16',
#   'End Date': '2013-03-15',
#   'Award Amount': 317861.76,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK12P0852',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2012-09-25',
#   'End Date': '2015-01-17',
#   'Award Amount': 87160.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK12F0159',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2012-09-20',
#   'End Date': '2012-10-05',
#   'Award Amount': 10584.07,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK12F0135',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2012-09-14',
#   'End Date': '2012-10-19',
#   'Award Amount': 347773.6,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK12F0132',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2012-09-17',
#   'End Date': '2012-10-12',
#   'Award Amount': 64809.78,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK12F0123',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2012-09-06',
#   'End Date': '2012-11-01',
#   'Award Amount': 57910.95,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK11F0138',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2011-09-12',
#   'End Date': '2011-10-31',
#   'Award Amount': 58834.34,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK11F0115',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2011-08-30',
#   'End Date': '2011-09-29',
#   'Award Amount': 16630.18,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P1144',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-09-10',
#   'End Date': '2010-10-13',
#   'Award Amount': 54611.93,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P1048',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-09-09',
#   'End Date': '2010-10-29',
#   'Award Amount': 1281341.25,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P1036',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-08-24',
#   'End Date': '2010-09-30',
#   'Award Amount': 17805.16,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P1001',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-08-14',
#   'End Date': '2010-09-30',
#   'Award Amount': 96425.64,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P0763',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-07-22',
#   'End Date': '2010-07-30',
#   'Award Amount': 307575.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P0496',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-05-03',
#   'End Date': '2010-06-15',
#   'Award Amount': 93335.5,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P0414',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-04-01',
#   'End Date': '2010-05-06',
#   'Award Amount': 48167.75,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P0270',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-02-22',
#   'End Date': '2011-02-17',
#   'Award Amount': 72811.67,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P0210',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-01-13',
#   'End Date': '2010-02-12',
#   'Award Amount': 67257.21,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10P0204',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-01-13',
#   'End Date': '2010-02-12',
#   'Award Amount': 62413.35,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10F0252',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-09-21',
#   'End Date': '2010-11-20',
#   'Award Amount': 179017.1,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10F0246',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-09-24',
#   'End Date': '2010-10-29',
#   'Award Amount': 78055.29,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10F0238',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-09-17',
#   'End Date': '2010-10-18',
#   'Award Amount': 35496.43,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10F0226',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-09-20',
#   'End Date': '2010-10-20',
#   'Award Amount': 36583.94,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10F0151',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-07-02',
#   'End Date': '2010-07-30',
#   'Award Amount': 62714.39,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK10F0072',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2010-03-17',
#   'End Date': '2010-04-16',
#   'Award Amount': 3508.4,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK09P1378',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2009-09-17',
#   'End Date': '2010-09-14',
#   'Award Amount': 205459.55,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK09P1244',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2009-09-05',
#   'End Date': '2009-09-15',
#   'Award Amount': 196888.17,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK09P1243',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2009-09-05',
#   'End Date': '2009-09-25',
#   'Award Amount': 181931.23,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91ZLK09P1062',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2009-07-24',
#   'End Date': '2010-07-16',
#   'Award Amount': 200624.36,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU014P0588',
#   'Recipient Name': 'ADVANCIA AERONAUTICS, LLC',
#   'Recipient DUNS Number': '792283272',
#   'Start Date': '2014-08-29',
#   'End Date': '2015-08-31',
#   'Award Amount': 363878.4,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU013F0125',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-09-13',
#   'End Date': '2013-11-15',
#   'Award Amount': 62202.14,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU012C0055',
#   'Recipient Name': 'AMG HEALTHCARE SERVICES, INC.',
#   'Recipient DUNS Number': '796313216',
#   'Start Date': '2012-09-14',
#   'End Date': '2013-09-30',
#   'Award Amount': 0.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DCA',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU011P0754',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2011-09-22',
#   'End Date': '2011-11-30',
#   'Award Amount': 62975.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU011P0726',
#   'Recipient Name': 'AMG HEALTHCARE SERVICES, INC.',
#   'Recipient DUNS Number': '796313216',
#   'Start Date': '2011-09-27',
#   'End Date': '2015-12-31',
#   'Award Amount': 1930049.24,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU010P0083',
#   'Recipient Name': 'ALTITUDE TECHNOLOGIES INC.',
#   'Recipient DUNS Number': '621904622',
#   'Start Date': '2009-11-24',
#   'End Date': '2009-12-21',
#   'Award Amount': 9214.62,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU009F0036',
#   'Recipient Name': 'ALTITUDE TECHNOLOGIES INC.',
#   'Recipient DUNS Number': '621904622',
#   'Start Date': '2009-02-17',
#   'End Date': '2009-02-27',
#   'Award Amount': 10267.45,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU008P0475',
#   'Recipient Name': 'ALTITUDE TECHNOLOGIES INC.',
#   'Recipient DUNS Number': '621904622',
#   'Start Date': '2008-08-22',
#   'End Date': '2008-09-15',
#   'Award Amount': 4282.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YU008P0406',
#   'Recipient Name': 'ALTITUDE TECHNOLOGIES INC.',
#   'Recipient DUNS Number': '621904622',
#   'Start Date': '2008-07-08',
#   'End Date': '2008-07-16',
#   'Award Amount': 5655.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YTZ20P0159',
#   'Recipient Name': '4S - SILVERSWORD SOFTWARE AND SERVICES, LLC',
#   'Recipient DUNS Number': '079719608',
#   'Start Date': '2020-08-15',
#   'End Date': '2022-10-31',
#   'Award Amount': 129926.4,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YTZ20P0065',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2020-01-27',
#   'End Date': '2021-01-26',
#   'Award Amount': 28243.8,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YTZ20C0025',
#   'Recipient Name': "AMERICA'S STAFFING PARTNER, INC.",
#   'Recipient DUNS Number': '800220415',
#   'Start Date': '2020-09-21',
#   'End Date': '2021-10-31',
#   'Award Amount': 793555.2,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YTZ20C0020',
#   'Recipient Name': "AMERICA'S STAFFING PARTNER, INC.",
#   'Recipient DUNS Number': '800220415',
#   'Start Date': '2020-09-21',
#   'End Date': '2021-10-31',
#   'Award Amount': 445900.8,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YTZ20C0017',
#   'Recipient Name': 'APPDDICTIONSTUDIO LIMITED LIABILITY COMPANY',
#   'Recipient DUNS Number': '968907076',
#   'Start Date': '2020-09-10',
#   'End Date': '2021-10-31',
#   'Award Amount': 159974.4,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YTZ20C0010',
#   'Recipient Name': 'AIMS LOCUM TENENS, LLC',
#   'Recipient DUNS Number': '013855798',
#   'Start Date': '2020-10-01',
#   'End Date': '2022-10-31',
#   'Award Amount': 99940.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W91YTZ20C0009',
#   'Recipient Name': 'APPDDICTIONSTUDIO LIMITED LIABILITY COMPANY',
#   'Recipient DUNS Number': '968907076',
#   'Start Date': '2020-05-15',
#   'End Date': '2022-10-31',
#   'Award Amount': 257111.35,
# ...
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HZ13P0102',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2013-03-29',
#   'End Date': '2013-04-04',
#   'Award Amount': 8013.12,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HZ08P0035',
#   'Recipient Name': 'ANDERSON ENVIRONMENTAL SERVICES, INC',
#   'Recipient DUNS Number': '102722456',
#   'Start Date': '2007-12-11',
#   'End Date': '2008-01-19',
#   'Award Amount': 10850.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HY20P0021',
#   'Recipient Name': 'ACE COMMUNICATIONS LTD. CO.',
#   'Recipient DUNS Number': '141051156',
#   'Start Date': '2020-09-09',
#   'End Date': '2021-09-09',
#   'Award Amount': 35617.59,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  {'Award ID': 'W912HY20C0038',
#   'Recipient Name': 'ARMITAGE ARCHITECTURE, P.C.',
#   'Recipient DUNS Number': '078526003',
#   'Start Date': '2021-01-31',
#   'End Date': '2021-04-03',
#   'Award Amount': 883715.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  {'Award ID': 'W912HQ20C0086',
#   'Recipient Name': 'ANALYTICX LLC',
#   'Recipient DUNS Number': '079123801',
#   'Start Date': '2020-09-28',
#   'End Date': '2021-09-29',
#   'Award Amount': 1291286.4,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HQ20C0085',
#   'Recipient Name': 'ANALYTICA LLC',
#   'Recipient DUNS Number': '829820070',
#   'Start Date': '2020-09-17',
#   'End Date': '2021-11-17',
#   'Award Amount': 256748.8,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HQ17F0020',
#   'Recipient Name': 'ADANTA, INC.',
#   'Recipient DUNS Number': '827627618',
#   'Start Date': '2017-05-03',
#   'End Date': '2017-06-01',
#   'Award Amount': 23628.55,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HQ12C0077',
#   'Recipient Name': 'ADVANCIA TECHNOLOGIES, LLC',
#   'Recipient DUNS Number': '801437471',
#   'Start Date': '2012-09-28',
#   'End Date': '2012-12-06',
#   'Award Amount': 11733.87,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DCA',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP20C1002',
#   'Recipient Name': 'A. JAMES GLOBAL SERVICES, INC.',
#   'Recipient DUNS Number': '079815682',
#   'Start Date': '2020-09-23',
#   'End Date': '2021-09-09',
#   'Award Amount': 335932.02,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP19F1119',
#   'Recipient Name': 'ARCHWAY SOLUTIONS LIMITED LIABILITY COMPANY',
#   'Recipient DUNS Number': '798785551',
#   'Start Date': '2019-07-01',
#   'End Date': '2019-09-30',
#   'Award Amount': 82671.02,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP19C7001',
#   'Recipient Name': 'AMES 1 , LLC',
#   'Recipient DUNS Number': '832565431',
#   'Start Date': '2019-09-27',
#   'End Date': '2021-04-22',
#   'Award Amount': 2941941.89,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP18C3005',
#   'Recipient Name': 'AMES 1 , LLC',
#   'Recipient DUNS Number': '832565431',
#   'Start Date': '2018-09-25',
#   'End Date': '2020-01-10',
#   'Award Amount': 947159.93,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP18C3003',
#   'Recipient Name': 'AMES 1 , LLC',
#   'Recipient DUNS Number': '832565431',
#   'Start Date': '2018-09-12',
#   'End Date': '2019-12-04',
#   'Award Amount': 971236.59,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP18C0009',
#   'Recipient Name': 'AMES 1 , LLC',
#   'Recipient DUNS Number': '832565431',
#   'Start Date': '2018-09-10',
#   'End Date': '2020-07-30',
#   'Award Amount': 956686.19,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP18C0003',
#   'Recipient Name': 'AMES 1 , LLC',
#   'Recipient DUNS Number': '832565431',
#   'Start Date': '2017-12-05',
#   'End Date': '2018-05-24',
#   'Award Amount': 1164674.62,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP16C0009',
#   'Recipient Name': 'ANNA LISA LUNA CONSTRUCTION, INC.',
#   'Recipient DUNS Number': '826375417',
#   'Start Date': '2016-08-04',
#   'End Date': '2017-08-04',
#   'Award Amount': 681528.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP14C0020',
#   'Recipient Name': 'AMES 1 , LLC',
#   'Recipient DUNS Number': '832565431',
#   'Start Date': '2014-09-30',
#   'End Date': '2016-10-25',
#   'Award Amount': 2141590.97,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP14C0015',
#   'Recipient Name': 'ACCURA ENGINEERING AND CONSULTING SERVICES, INC.',
#   'Recipient DUNS Number': '168562267',
#   'Start Date': '2014-09-29',
#   'End Date': '2016-12-31',
#   'Award Amount': 2404009.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HP13C0017',
#   'Recipient Name': 'ACCURA ENGINEERING AND CONSULTING SERVICES, INC.',
#   'Recipient DUNS Number': '168562267',
#   'Start Date': '2013-09-28',
#   'End Date': '2015-12-31',
#   'Award Amount': 2232530.01,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HN20C5003',
#   'Recipient Name': 'A. JAMES GLOBAL SERVICES, INC.',
#   'Recipient DUNS Number': '079815682',
#   'Start Date': '2020-05-07',
#   'End Date': '2022-05-31',
#   'Award Amount': 2098403.97,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  {'Award ID': 'W912HN20C1000',
#   'Recipient Name': 'AEROSTAR ENVIRONMENTAL AND CONSTRUCTION LLC',
#   'Recipient DUNS Number': '081292274',
#   'Start Date': '2020-09-25',
#   'End Date': '2024-09-25',
#   'Award Amount': 2789790.68,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HN19C4004',
#   'Recipient Name': 'AMES 1 , LLC',
#   'Recipient DUNS Number': '832565431',
#   'Start Date': '2019-08-16',
#   'End Date': '2020-05-23',
#   'Award Amount': 1703492.74,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912HN14C0016',
#   'Recipient Name': 'ALUTIIQ GENERAL CONTRACTORS, LLC',
#   'Recipient DUNS Number': '830400581',
#   'Start Date': '2014-09-29',
#   'End Date': '2015-09-10',
#   'Award Amount': 7858535.1,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912GY15F0001',
#   'Recipient Name': 'ARETEC, INC.',
#   'Recipient DUNS Number': '606205412',
#   'Start Date': '2014-10-07',
#   'End Date': '2020-04-30',
#   'Award Amount': 60486.56,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DELIVERY ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912GY14P0070',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2014-07-29',
#   'End Date': '2014-08-28',
#   'Award Amount': 25807.2,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912GY14P0049',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2014-05-13',
#   'End Date': '2015-01-26',
#   'Award Amount': 23983.7,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PO',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912ES20P0109',
#   'Recipient Name': 'ADVANCED DESIGN CONTRACTING, LLC',
#   'Recipient DUNS Number': '017353402',
#   'Start Date': '2020-10-15',
#   'End Date': '2021-06-30',
#   'Award Amount': 175619.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  {'Award ID': 'W912ES20P0101',
#   'Recipient Name': 'ADVANCED DESIGN CONTRACTING, LLC',
#   'Recipient DUNS Number': '017353402',
#   'Start Date': '2020-10-31',
#   'End Date': '2021-06-30',
#   'Award Amount': 211195.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  {'Award ID': 'W912ES15P0017',
#   'Recipient Name': 'ALL BUSINESS MACHINES, INC.',
#   'Recipient DUNS Number': '104178756',
#   'Start Date': '2015-01-06',
#   'End Date': '2015-07-02',
#   'Award Amount': 13462.39,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912EQ21P0017',
#   'Recipient Name': '3T FEDERAL SOLUTIONS LLC',
#   'Recipient DUNS Number': '557502155',
#   'Start Date': '2021-01-27',
#   'End Date': '2021-02-18',
#   'Award Amount': 0.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Department of Defense',
#   'Funding Sub Agency': 'Department of the Army'},
#  {'Award ID': 'W912EQ21C0016',
#   'Recipient Name': 'A ROCK CONSTRUCTION CO., INC',
#   'Recipient DUNS Number': '806307794',
#   'Start Date': '2021-10-14',
#   'End Date': '2022-08-12',
#   'Award Amount': 2129087.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  {'Award ID': 'W912EQ20P0042',
#   'Recipient Name': 'A ROCK CONSTRUCTION CO., INC',
#   'Recipient DUNS Number': '806307794',
#   'Start Date': '2020-07-12',
#   'End Date': '2020-07-30',
#   'Award Amount': 74520.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'PURCHASE ORDER',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  {'Award ID': 'W912EQ20C0013',
#   'Recipient Name': 'A ROCK CONSTRUCTION CO., INC',
#   'Recipient DUNS Number': '806307794',
#   'Start Date': '2020-07-29',
#   'End Date': '2021-03-30',
#   'Award Amount': 2468340.0,
#   'Awarding Agency': 'Department of Defense',
#   'Awarding Sub Agency': 'Department of the Army',
#   'Contract Award Type': 'DEFINITIVE CONTRACT',
#   'Award Type': None,
#   'Funding Agency': 'Corps of Engineers - Civil Works',
#   'Funding Sub Agency': 'U.S. Army Corps of Engineers - Civil Program Financing Only'},
#  ...]

# %%
awards_df.to_csv('awards_df.csv')

# %%
import json
out_file = open("awards_df.json", "w") 
    
json.dump(award_list, out_file, indent = 6) 
    
out_file.close()

# %%
# award types: 
# A = GWAC
# B = IDC - Indefinate Delivery Contract
# C = FSS - GSA OR VA Federal Suppy Schedule 
# D = BOA - Basic Ordering Agreement
